# %% [markdown]
# <a href="https://colab.research.google.com/github/Saadmoquim/physicscode/blob/day1/PHY6350.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from numpy import linspace,sin,cos


# Take 100 equally spaced points between 0 and 10 and store them as a list
numpoints = 100
x = linspace(-10,10,numpoints)

# Calculate the value of sin(x) and each point and store in a list y
y = sin(x)

# Make a plot and show the results
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import linspace,sin,cos


# Take 100 equally spaced points between 0 and 10 and store them as a list
numpoints = 100
x = linspace(-10,10,numpoints)

# Calculate the value of sin(x) and each point and store in a list y
y = cos(x)**2+sin(x)**2

# Make a plot and show the results
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np

def gaussian(x, mu, sigma):
    return np.exp(-(x - mu)**2 / (2 * sigma**2)) / (sigma * np.sqrt(2 * np.pi))

numpoints=100
x=linspace(-10,10,numpoints)

y=gaussian(x,0,1)

plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
